# %% [markdown]
# <a href="https://colab.research.google.com/github/TREX99/dnc_explorer/blob/master/1%EC%A3%BC%EC%B0%A8-%EA%B3%BC%EC%A0%9C%231.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
data = np.arange(1, 11, 1)

# %%
data2 = np.array((1,10, 1))

# %%
print(data)
# vvector 가정
# Out:
# [1 2 3 4 5 6 7 8 9]
